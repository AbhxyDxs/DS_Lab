# %%
# !pip install pandas
# !pip install -U scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
#Creating test dataset for DecisionTree
np.random.seed(15) #Seed ensures the same sequence of randomness
data = {
    'Color':np.random.choice(['Red','Blue','Green','Black','White'],25),
    'Brand':np.random.choice(['Ford','Ferrari','Nissan','Volkswagen','Cheverlot'],25),
    'Year':np.random.randint(2018,2023,size=25),
    'Seats':np.random.randint(4,8,25),
    'Kilometers_Run':np.random.randint(35000,65000,25),
    'Buy':np.random.choice(['Yes','No'],25)
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Color       Brand  Year  Seats  Kilometers_Run  Buy
# 0     Red     Ferrari  2021      4           56308  Yes
# 1   White      Nissan  2020      6           60224   No
# 2     Red        Ford  2019      6           60959   No
# 3   White        Ford  2021      5           57794  Yes
# 4   Black        Ford  2020      7           36770  Yes
# 5   Black   Cheverlot  2020      7           63363   No
# 6    Blue  Volkswagen  2020      4           44387   No
# 7     Red   Cheverlot  2020      7           59893  Yes
# 8   Green      Nissan  2018      5           42650   No
# 9   White      Nissan  2020      4           51492   No
# 10   Blue        Ford  2018      7           38279   No
# 11  Black  Volkswagen  2022      7           38669   No
# 12  White        Ford  2022      4           62724  Yes
# 13  White   Cheverlot  2022      7           59127  Yes
# 14    Red  Volkswagen  2021      7           53371  Yes
# 15  Green     Ferrari  2022      4           51300   No
# 16   Blue        Ford  2018      6           56692   No
# 17   Blue        Ford  2019      5           59603   No
# 18    Red   Cheverlot  2018      6           39477  Yes
# 19  Green        Ford  2022      6           48688  Yes
# 20  Green   Cheverlot  2018      5           36961   No
# 21  Black     Ferrari  2021      4           54668   No
# 22  Green      Nissan  2020      4           63153   No
# 23   Blue        Ford  2022      7           38956  Yes
# 24    Red   Cheverlot  2020      6           43916   No

# %%
#Mapping non-numeric values with numeric values
df['Color'] = df['Color'].map({'Red':0,'Blue':1,'Green':2,'Black':3,'White':4})
df['Brand'] = df['Color'].map({'Ford':0,'Ferrari':1,'Nissan':2,'Volkswagen':3,'Cheverlot':4})
df['Buy'] = df['Buy'].map({'No':0,'Yes':1})

# %%
#Creating two dataframes
#One with the Features - X
#One with the Target Class - Y
X = df[['Color','Brand','Year','Seats','Kilometers_Run']]
Y = df[['Buy']]

# %%
#Creating a DecisionTreeClassifier Object
clf = DecisionTreeClassifier()
#Fitting the classifier with Feature and Target dataframes
clf.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
#Plotting the Decision Tree
plt.figure.figsize=(16,6) #figsize values are width and height in inches
#plot_tree(clf) is enough for plotting
plot_tree(clf,class_names=['No','Yes'],feature_names=X.columns,filled=True,rounded=True)
plt.show()
